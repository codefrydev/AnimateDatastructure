// %%
using System;
using System.Collections.Generic;
using System.Text;
using System.Linq;
using System.IO;

// %%
public enum FolderName
{
    Greedy,
    Matrix,
    SlidingWindow,
    Tree,
    Array,
    Stack,
    DP,
    Linear,
    BinarySearch,
    TwoPointer
}

// %%
var folder = FolderName.TwoPointer;
folder
// Out:
// <span>TwoPointer</span>

// %%
var fileName = "minimum-absolute-distance-between-mirror-pairs";
var folderName = folder.ToString();
folderName
// Out:
// TwoPointer

// %%
var newFileAndFolderPath = Path.Combine(Directory.GetCurrentDirectory() , folderName);
newFileAndFolderPath
// Out:
// /Users/codefrydev/Desktop/SourceCode/AnimateDatastructure/TwoPointer

// %%
public class ProblemData
{
    public string ProblemUri { get; set; }
    public string ProblemName { get; set; }
    public string ProblemDescription { get; set; }
    public string ProblemSolution { get; set; }
    public string Difficulty { get; set; }
    public List<string> Topics { get; set; }
    public int ProblemNumber { get; set; }
}

// %%
Directory.CreateDirectory(newFileAndFolderPath);

var jsonPath = Path.Combine(newFileAndFolderPath, fileName + ".json");
var htmlPath = Path.Combine(newFileAndFolderPath, fileName + ".html");

if (!File.Exists(jsonPath))
{
    var data = new ProblemData
    {
        ProblemUri = $"https://leetcode.com/problems/{fileName}",
        ProblemName = "Maximum Distance Between a Pair of Values",
        ProblemDescription = """


You are given two non-increasing 0-indexed integer arrays nums1​​​​​​ and nums2​​​​​​.

A pair of indices (i, j), where 0 <= i < nums1.length and 0 <= j < nums2.length, is valid if both i <= j and nums1[i] <= nums2[j]. The distance of the pair is j - i​​​​.

Return the maximum distance of any valid pair (i, j). If there are no valid pairs, return 0.

An array arr is non-increasing if arr[i-1] >= arr[i] for every 1 <= i < arr.length.

 

 
""",
        ProblemSolution = folderName,
        Difficulty = "Medium",
        Topics = """


Senior
Array
Two Pointers
Binary Search
Weekly Contest 240

""".Split([' ','\n']).Select(x=>x.Trim()).Where(x=>x.Length>0).ToList(),


        ProblemNumber = 1855
    };

    var json = System.Text.Json.JsonSerializer.Serialize(data, new System.Text.Json.JsonSerializerOptions
    {
        WriteIndented = true
    });

    File.WriteAllText(jsonPath, json);
}

if (!File.Exists(htmlPath))
{
    File.WriteAllText(htmlPath, "");
}
